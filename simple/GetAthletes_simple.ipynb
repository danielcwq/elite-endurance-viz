# %% [markdown]
# Let's see whether BS4 for this task is sufficient. The end goal is to generate a list of names, after which we will run it through Strava

# %%
import requests
import pandas as pd

# %%
# !pip install bs4
from bs4 import BeautifulSoup

# %% [markdown]
# Some things to take note:
# 1. Repeats are ignored (because we want unique names).
# 2. Eventually we want to create a list of ALL names across the various disciplines, so we must take out repeats in that aspect too

# %% [markdown]
# Realised today that indoor results are actually factored into this as well. This was probably already here yesterday, but didn't think about that. What would be more interesting is creating a list of all times (both indoor and outdoor) that the athlete has run for part 1(b). Then we can look at FORM going into the Olympics, probably can include things like date for part 1(b) too. For now, just raw highest points and time going into OLY, regardless of indoor / outdoor for part 1(a).

# %%
def get_event_results(urls, discipline):
    results = []
    for url in urls:
        response = requests.get(url)
        data = response.text
        soup = BeautifulSoup(data, 'html.parser')
        table = soup.find('table')
        for row in table.find_all('tr')[1:]:
            cols = row.find_all('td')
            if len(cols) > 1:
                mark = cols[1].text.strip()
                competitor = cols[3].text.strip()
                nationality = cols[5].text.strip()
                location = cols[-3].text.strip()
                result_score = cols[-1].text.strip()

                results.append({
                    'Mark': mark,
                    'Competitor': competitor,
                    'Nat': nationality,
                    'Location': location,
                    'Results Score': result_score
                })
    df = pd.DataFrame(results)
    df.insert(4, 'Discipline', discipline)
    return df

# %% [markdown]
# #800m Men (also just because 800m can be considered a distance event)

# %%
urls_800m = ["https://worldathletics.org/records/toplists/middlelong/800-metres/all/men/senior/2024?regionType=world&timing=electronic&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229501&ageCategory=senior", "https://worldathletics.org/records/toplists/middlelong/800-metres/all/men/senior/2024?regionType=world&timing=electronic&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229501&ageCategory=senior","https://worldathletics.org/records/toplists/middlelong/800-metres/all/men/senior/2024?regionType=world&timing=electronic&page=3&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229501&ageCategory=senior", "https://worldathletics.org/records/toplists/middlelong/800-metres/all/men/senior/2024?regionType=world&timing=electronic&page=4&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229501&ageCategory=senior"]

# %%
df_800m = get_event_results(urls_800m, '800m')
df_800m
# Out:
#         Mark               Competitor  Nat  \
# 0    1:41.46           Djamel SEDJATI  ALG
# 1    1:41.58        Emmanuel WANYONYI  KEN
# 2    1:41.61             Gabriel TUAL  FRA
# 3    1:42.04          Mohamed ATTAOUI  ESP
# 4    1:42.08  Aaron Kemei CHEMININGWA  KEN
# ..       ...                      ...  ...
# 395  1:47.87             Sacha CULTRU  FRA
# 396  1:47.88          John FITZSIMONS  IRL
# 397  1:47.88        Baptiste MISCHLER  FRA
# 398  1:47.88       Alexander STEPANOV  GER
# 399  1:47.89           Oskars BAMBALS  LAT
#
#                                               Location Discipline  \
# 0                         Stade Louis II, Monaco (MON)       800m
# 1                          Stade Charléty, Paris (FRA)       800m
# 2                          Stade Charléty, Paris (FRA)       800m
# 3                         Stade Louis II, Monaco (MON)       800m
# 4                          Stade Charléty, Paris (FRA)       800m
# ...

# %% [markdown]
# #1500m Men (deepest fields)

# %%
urls_1500m = ["https://worldathletics.org/records/toplists/middlelong/1500-metres/all/men/senior/2024?regionType=world&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229502&ageCategory=senior", "https://worldathletics.org/records/toplists/middlelong/1500-metres/all/men/senior/2024?regionType=world&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229502&ageCategory=senior", "https://worldathletics.org/records/toplists/middlelong/1500-metres/all/men/senior/2024?regionType=world&page=3&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229502&ageCategory=senior", "https://worldathletics.org/records/toplists/middlelong/1500-metres/all/men/senior/2024?regionType=world&page=4&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229502&ageCategory=senior"]

# %%
df_1500m = get_event_results(urls_1500m, '1500m')
df_1500m
# Out:
#         Mark          Competitor  Nat  \
# 0    3:26.73  Jakob INGEBRIGTSEN  NOR
# 1    3:28.71   Timothy CHERUIYOT  KEN
# 2    3:28.80         Brian KOMEN  KEN
# 3    3:29.13        Yared NUGUSE  USA
# 4    3:30.59         Cole HOCKER  USA
# ..       ...                 ...  ...
# 395  3:40.43           Joe EWING  GBR
# 396  3:40.43       Isaiah GIVENS  USA
# 397  3:40.46  Brian Muange MUSAU  KEN
# 398  3:40.47       Andrew PAYTON  USA
# 399  3:40.48     Nassim HASSAOUS  ESP
#
#                                              Location Discipline Results Score
# 0                        Stade Louis II, Monaco (MON)      1500m          1292
# 1                        Stade Louis II, Monaco (MON)      1500m          1263
# 2                        Stade Louis II, Monaco (MON)      1500m          1262
# 3                        Stade Louis II, Monaco (MON)      1500m          1257
# 4                     Hayward Field, Eugene, OR (USA)      1500m          1236
# ...

# %% [markdown]
# #3000m SC

# %%
urls_3000m = ["https://worldathletics.org/records/toplists/middlelong/3000-metres-steeplechase/all/men/senior/2024?regionType=world&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229614&ageCategory=senior", "https://worldathletics.org/records/toplists/middlelong/3000-metres-steeplechase/all/men/senior/2024?regionType=world&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229614&ageCategory=senior"]

# %%
df_3000mSC = get_event_results(urls_3000m, '3000mSC')
df_3000mSC
# Out:
#         Mark        Competitor  Nat  \
# 0    8:01.63     Lamecha GIRMA  ETH
# 1    8:02.36       Abrham SIME  ETH
# 2    8:02.36        Amos SEREM  KEN
# 3    8:05.78     Samuel FIREWU  ETH
# 4    8:06.70   Abraham KIBIWOT  KEN
# ..       ...               ...  ...
# 195  8:38.15   Titouan LE GRIX  FRA
# 196  8:38.25      Luke LABATTE  USA
# 197  8:38.37       Finley DALY  IRL
# 198  8:38.43  Alejandro ORTUÑO  ESP
# 199  8:38.43      Kota YOSHIDA  JPN
#
#                                               Location Discipline  \
# 0                      Olympiastadion, Stockholm (SWE)    3000mSC
# 1                          Stade Charléty, Paris (FRA)    3000mSC
# 2                          Stade Charléty, Paris (FRA)    3000mSC
# 3                      Olympiastadion, Stockholm (SWE)    3000mSC
# 4                          Stade Charléty, Paris (FRA)    3000mSC
# ..                                                 ...        ...
# ...

# %% [markdown]
# #5000m

# %%
urls_5000m = ['https://worldathletics.org/records/toplists/middlelong/5000-metres/all/men/senior/2024?regionType=world&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229609&ageCategory=senior', 'https://worldathletics.org/records/toplists/middlelong/5000-metres/all/men/senior/2024?regionType=world&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229609&ageCategory=senior', 'https://worldathletics.org/records/toplists/middlelong/5000-metres/all/men/senior/2024?regionType=world&page=3&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229609&ageCategory=senior']

# %%
df_5000m = get_event_results(urls_5000m, '5000m')
df_5000m
# Out:
#          Mark                 Competitor  Nat  \
# 0    12:36.73            Hagos GEBRHIWET  ETH
# 1    12:38.95             Yomif KEJELCHA  ETH
# 2    12:40.96              Jacob KIPLIMO  UGA
# 3    12:48.10       Thierry NDIKUMWENAYO  ESP
# 4    12:49.65              Addisu YIHUNE  ETH
# ..        ...                        ...  ...
# 295  13:31.51                Gary MARTIN  USA
# 296  13:31.55  Alex Kipirech KIPCHIRCHIR  KEN
# 297  13:31.61                Ryuji MIURA  JPN
# 298  13:31.81                Peter LYNCH  IRL
# 299  13:31.95           Tatsuya MARUYAMA  JPN
#
#                                               Location Discipline  \
# 0                          Bislett Stadion, Oslo (NOR)      5000m
# 1                          Bislett Stadion, Oslo (NOR)      5000m
# 2                          Bislett Stadion, Oslo (NOR)      5000m
# 3                          Bislett Stadion, Oslo (NOR)      5000m
# 4                          Bislett Stadion, Oslo (NOR)      5000m
# ...

# %% [markdown]
# #10000m

# %%
urls_10000m = ["https://worldathletics.org/records/toplists/middlelong/10000-metres/all/men/senior/2024?regionType=world&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229610&ageCategory=senior","https://worldathletics.org/records/toplists/middlelong/10000-metres/all/men/senior/2024?regionType=world&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229610&ageCategory=senior","https://worldathletics.org/records/toplists/middlelong/10000-metres/all/men/senior/2024?regionType=world&page=3&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229610&ageCategory=senior"]

# %%
df_10000m = get_event_results(urls_10000m, '10000m')
df_10000m
# Out:
#          Mark             Competitor  Nat  \
# 0    26:31.01         Yomif KEJELCHA  ETH
# 1    26:31.13         Berihu AREGAWI  ETH
# 2    26:34.93         Selemon BAREGA  ETH
# 3    26:37.93          Biniam MEHARY  ETH
# 4    26:42.65           Gemechu DIDA  ETH
# ..        ...                    ...  ...
# 295  28:32.28            Eiki KOGURE  JPN
# 296  28:32.36        Kazura MUNAKATA  JPN
# 297  28:32.41          Skylar STIDAM  USA
# 298  28:32.42           Luca ALFIERI  ITA
# 299  28:33.03  Roncer Kipkorir KONGA  KEN
#
#                                               Location Discipline  \
# 0            Estadio Enrique Lopez Cuenca, Nerja (ESP)     10000m
# 1            Estadio Enrique Lopez Cuenca, Nerja (ESP)     10000m
# 2            Estadio Enrique Lopez Cuenca, Nerja (ESP)     10000m
# 3            Estadio Enrique Lopez Cuenca, Nerja (ESP)     10000m
# 4            Estadio Enrique Lopez Cuenca, Nerja (ESP)     10000m
# ...

# %% [markdown]
# #HM

# %%
urls_HM = ["https://worldathletics.org/records/toplists/road-running/half-marathon/all/men/senior/2024?regionType=world&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229633&ageCategory=senior","https://worldathletics.org/records/toplists/road-running/half-marathon/all/men/senior/2024?regionType=world&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229633&ageCategory=senior","https://worldathletics.org/records/toplists/road-running/half-marathon/all/men/senior/2024?regionType=world&page=3&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229633&ageCategory=senior"]

# %%
df_HM = get_event_results(urls_HM, 'HM')
df_HM
# Out:
#         Mark             Competitor  Nat  \
# 0      58:24  Sabastian Kimaru SAWE  KEN
# 1      58:45         Daniel MATEIKO  KEN
# 2      58:50             John KORIR  KEN
# 3      58:55   Isaia Kipkoech LASOI  KEN
# 4      59:21          Bravin KIPROP  KEN
# ..       ...                    ...  ...
# 295  1:02:09          Koki MARUYAMA  JPN
# 296  1:02:09           Stan NIESTEN  NED
# 297  1:02:09          Suldan HASSAN  SWE
# 298  1:02:10          Ren YAMAGUCHI  JPN
# 299  1:02:10      Othmane EL GOUMRI  MAR
#
#                                          Location Discipline Results Score
# 0                                     Praha (CZE)         HM          1251
# 1                            Ras Al Khaimah (UAE)         HM          1237
# 2                            Ras Al Khaimah (UAE)         HM          1234
# 3                            Ras Al Khaimah (UAE)         HM          1230
# 4                                   Sevilla (ESP)         HM          1213
# ...

# %% [markdown]
# #Marathon (deep field)

# %%
urls_marathon = ["https://worldathletics.org/records/toplists/road-running/marathon/all/men/senior/2024?regionType=world&page=1&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229634&ageCategory=senior","https://worldathletics.org/records/toplists/road-running/marathon/all/men/senior/2024?regionType=world&page=2&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229634&ageCategory=senior","https://worldathletics.org/records/toplists/road-running/marathon/all/men/senior/2024?regionType=world&page=3&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229634&ageCategory=senior", "https://worldathletics.org/records/toplists/road-running/marathon/all/men/senior/2024?regionType=world&page=4&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229634&ageCategory=senior", "https://worldathletics.org/records/toplists/road-running/marathon/all/men/senior/2024?regionType=world&page=5&bestResultsOnly=true&maxResultsByCountry=all&eventId=10229634&ageCategory=senior"]

# %%
df_M = get_event_results(urls_marathon, 'M')
df_M
# Out:
#         Mark             Competitor  Nat         Location Discipline  \
# 0    2:02:16         Benson KIPRUTO  KEN      Tokyo (JPN)          M
# 1    2:02:55       Timothy KIPLAGAT  KEN      Tokyo (JPN)          M
# 2    2:03:27          Deresa GELETA  ETH    Sevilla (ESP)          M
# 3    2:03:47         Morhad AMDOUNI  FRA    Sevilla (ESP)          M
# 4    2:04:01       Alexander MUNYAO  KEN     London (GBR)          M
# ..       ...                    ...  ...              ...        ...
# 495  2:13:42  Sendeku Alelgn AMOGNE  ETH      Izmir (TUR)          M
# 496  2:13:42           Florian CARO  FRA       Caen (FRA)          M
# 497  2:13:43        Frank FUTSELAAR  NED  Rotterdam (NED)          M
# 498  2:13:43          Asefa MENGSTU  ETH    Qingdao (CHN)          M
# 499  2:13:44        Takuya KITASAKI  JPN      Osaka (JPN)          M
#
#     Results Score
# 0            1292
# 1            1281
# 2            1271
# 3            1266
# 4            1262
# ..            ...
# ...

# %% [markdown]
# #Combined dataframes

# %%
combined_disciplines = pd.concat([df_1500m, df_3000mSC, df_5000m, df_10000m, df_HM, df_M], ignore_index=True)
combined_disciplines
# Out:
#          Mark             Competitor  Nat                         Location  \
# 0     3:26.73     Jakob INGEBRIGTSEN  NOR     Stade Louis II, Monaco (MON)
# 1     3:28.71      Timothy CHERUIYOT  KEN     Stade Louis II, Monaco (MON)
# 2     3:28.80            Brian KOMEN  KEN     Stade Louis II, Monaco (MON)
# 3     3:29.13           Yared NUGUSE  USA     Stade Louis II, Monaco (MON)
# 4     3:30.59            Cole HOCKER  USA  Hayward Field, Eugene, OR (USA)
# ...       ...                    ...  ...                              ...
# 1995  2:13:42  Sendeku Alelgn AMOGNE  ETH                      Izmir (TUR)
# 1996  2:13:42           Florian CARO  FRA                       Caen (FRA)
# 1997  2:13:43        Frank FUTSELAAR  NED                  Rotterdam (NED)
# 1998  2:13:43          Asefa MENGSTU  ETH                    Qingdao (CHN)
# 1999  2:13:44        Takuya KITASAKI  JPN                      Osaka (JPN)
#
#      Discipline Results Score
# 0         1500m          1292
# ...

# %%
combined_disciplines.to_csv('combined_disciplines_elite.csv', index=False)

# %% [markdown]
# The following code will allow us to see if there are any repeated entries of names and times.

# %% [markdown]
# #Duplicate Entries (i.e. folks who are too cracked)

# %%
combined_disciplines_sorted = combined_disciplines.sort_values(by=['Competitor', 'Discipline'])
duplicates_sorted = combined_disciplines_sorted[combined_disciplines_sorted.duplicated('Competitor', keep=False)]
duplicates_sorted
# Out:
#           Mark              Competitor  Nat  \
# 1104  28:19.43         Aarón LAS HERAS  ESP
# 714   13:16.68         Aarón LAS HERAS  ESP
# 1269   1:00:45       Abbabiya SIMBASSA  USA
# 1901   2:12:21       Abbabiya SIMBASSA  USA
# 308    3:39.29  Abderrahman EL KHAYAMI  ESP
# ...        ...                     ...  ...
# 1801   2:10:50            Zach PANNING  USA
# 980   27:46.55        Zakariya MAHAMED  GBR
# 809   13:24.83        Zakariya MAHAMED  GBR
# 1260   1:00:41           Zouhair TALBI  MAR
# 1547   2:06:39           Zouhair TALBI  MAR
#
#                                                Location Discipline  \
# 1104           Cougar Athletic Stadium, Azusa, CA (USA)     10000m
# 714   Boston Univ. Track & Tennis Center, Boston, MA...      5000m
# 1269                                  Houston, TX (USA)         HM
# 1901                                  Orlando, FL (USA)          M
# 308              Polideportivo Municipal, Andújar (ESP)      1500m
# ...

# %%
duplicates_sorted.to_csv('duplicates_sorted_by_name.csv', index=False)

# %%
# Ensure 'Results Score' is numeric
duplicates_sorted['Results Score'] = pd.to_numeric(duplicates_sorted['Results Score'], errors='coerce')

# Aggregate with corrected data types
aggregated = duplicates_sorted.groupby('Competitor').agg(
    Average_Results_Score=('Results Score', 'mean'),  # Calculate average Results Score
    Total_Results_Score=('Results Score', 'sum'),  # Sum of corrected Results Score
    Disciplines=('Discipline', lambda x: list(set(x))),  # Collect unique disciplines
    Discipline_Count=('Discipline', 'size')  # Count disciplines
)

aggregated_sorted = aggregated.sort_values(by=['Average_Results_Score'], ascending=False)
aggregated_sorted
# Out:
# <ipython-input-23-2ee5201aafc5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_sorted['Results Score'] = pd.to_numeric(duplicates_sorted['Results Score'], errors='coerce')
#                     Average_Results_Score  Total_Results_Score  \
# Competitor
# Yomif KEJELCHA                     1280.5                 2561
# Berihu AREGAWI                     1256.0                 2512
# Edwin KURGAT                       1256.0                 2512
# Yared NUGUSE                       1256.0                 2512
# Hagos GEBRHIWET                    1251.0                 2502
# ...                                   ...                  ...
# Kaisei SUGIYAMA                    1100.5                 2201
# ...

# %%
aggregated_sorted.to_csv('aggregated_sorted_by_highest_average.csv', index=False)

# %% [markdown]
# #Map Visualisation

# %%
# !pip install folium

# %%
import folium
from folium.plugins import MarkerCluster

# %%
country_counts = combined_disciplines['Nat'].value_counts()
country_df = country_counts.to_frame() #why am i running into a bug that shows a key error for Nat?????

# %%
country_df
# Out:
#      count
# Nat
# KEN    422
# JPN    336
# USA    252
# ETH    182
# FRA     85
# ..     ...
# RUS      1
# EGY      1
# BLR      1
# ARM      1
# EST      1
#
# [78 rows x 1 columns]

# %%
country_df.head(10)
# Out:
#      count
# Nat
# KEN    422
# JPN    336
# USA    252
# ETH    182
# FRA     85
# GBR     68
# ESP     61
# MAR     44
# AUS     38
# CAN     37

# %%
coordinates = {
    'KEN': (-0.0236, 37.9062),
    'JPN': (36.2048, 138.2529),
    'USA': (37.0902, -95.7129),
    'ETH': (9.145, 40.4897),
    'FRA': (46.2276, 2.2137),
    'GBR': (55.3781, -3.4360),
    'ESP': (40.4637, -3.7492),
    'MAR': (31.7917, -7.0926),
    'AUS': (-25.2744, 133.7751),
    'CAN': (56.1304, -106.3468),
    'GER': (51.1657, 10.4515),
    'ITA': (41.8719, 12.5674),
    'ERI': (15.1794, 39.7823),
    'UGA': (1.3733, 32.2903),
    'IRL': (53.4129, -8.2439),
    'NOR': (60.4720, 8.4689),
    'BEL': (50.5039, 4.4699),
    'SWE': (60.1282, 18.6435),
    'RSA': (-30.5595, 22.9375),
    'NED': (52.1326, 5.2913),
    'CHN': (35.8617, 104.1954),
    'ISR': (31.0461, 34.8516),
    'SUI': (46.8182, 8.2275),
    'ALG': (28.0339, 1.6596),
    'POR': (39.3999, -8.2245),
    'MEX': (23.6345, -102.5528),
    'NZL': (-40.9006, 174.8860),
    'DEN': (56.2639, 9.5018),
    'BDI': (-3.3731, 29.9189),
    'IND': (20.5937, 78.9629),
    'CZE': (49.8175, 15.4730),
    'POL': (51.9194, 19.1451),
    'TUR': (38.9637, 35.2433),
    'DJI': (11.8251, 42.5903),
    'TUN': (33.8869, 9.5375),
    'BRA': (-14.2350, -51.9253),
    'AUT': (47.5162, 14.5501),
    'BRN': (26.0667, 50.5577),
    'NAM': (-22.9576, 18.4904),
    'FIN': (61.9241, 25.7482),
    'TAN': (-6.3690, 34.8888),
    'URU': (-32.5228, -55.7658),
    'MGL': (46.8625, 103.8467),
    'HUN': (47.1625, 19.5033),
    'GUA': (15.7835, -90.2308),
    'PUR': (18.2208, -66.5901),
    'SOM': (5.1521, 46.1996),
    'LUX': (49.8153, 6.1296),
    'MDA': (47.4116, 28.3699),
    'LES': (-29.60999, 28.2336),
    'ZIM': (-19.0154, 29.1549),
    'CPV': (16.5388, -23.0418),
    'GHA': (7.9465, -1.0232),
    'RWA': (-1.9403, 29.8739),
    'AND': (42.5462, 1.6016),
    'SRB': (44.0165, 21.0059),
    'ARG': (-38.4161, -63.6167),
    'COL': (4.5709, -74.2973),
    'ISL': (64.9631, -19.0208),
    'QAT': (25.3548, 51.1839),
    'CHI': (-35.6751, -71.5430),
    'PRK': (40.3399, 127.5101),
    'PAN': (8.53798, -80.7821),
    'PER': (-9.1900, -75.0152),
    'PAR': (-23.4425, -58.4438),
    'ECU': (-1.8312, -78.1834),
    'KSA': (23.8859, 45.0792),
    'MKD': (41.6086, 21.7453),
    'THA': (15.8700, 100.9925),
    'LAT': (56.8796, 24.6032),
    'SSD': (7.8627, 29.6949),
    'LTU': (55.1694, 23.8813),
    'RUS': (61.5240, 105.3188),
    'EGY': (26.8206, 30.8025),
    'BLR': (53.7098, 27.9534),
    'ARM': (40.0691, 45.0382),
    'EST': (58.5953, 25.0136),
}

# %%
coordinates_df = pd.DataFrame(coordinates).T.reset_index()
coordinates_df.columns = ['Nat', 'Lat', 'Long']
merged_df = pd.merge(country_df, coordinates_df, on='Nat')

# %%
merged_df
# Out:
#     Nat  count      Lat      Long
# 0   KEN    422  -0.0236   37.9062
# 1   JPN    336  36.2048  138.2529
# 2   USA    252  37.0902  -95.7129
# 3   ETH    182   9.1450   40.4897
# 4   FRA     85  46.2276    2.2137
# ..  ...    ...      ...       ...
# 72  RUS      1  61.5240  105.3188
# 73  EGY      1  26.8206   30.8025
# 74  BLR      1  53.7098   27.9534
# 75  ARM      1  40.0691   45.0382
# 76  EST      1  58.5953   25.0136
#
# [77 rows x 4 columns]

# %%
map = folium.Map(location = [20,0], zoom_start = 2)
for idx, row in merged_df.iterrows():
  folium.CircleMarker(
      location = [row['Lat'], row['Long']],
      radius = row['count']/20,
      popup = f"{row['Nat']}: {row['count']}",
      color='blue',
        fill=True,
        fill_color='blue'
  ).add_to(map)
  folium.map.Marker(
        [row['Lat'], row['Long']],
        icon=folium.DivIcon(
            icon_size=(150,36),
            icon_anchor=(0,0),
            html=f'<div style="font-size: 6pt; color : black">{row["count"]}</div>',
            )
        ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #Depre

# %%
duplicates_competitor = combined_disciplines[combined_disciplines.duplicated('Competitor', keep=False)]
duplicates_competitor
# Out:
#          Mark          Competitor  Nat Results Score Discipline
# 0     3:26.73  Jakob INGEBRIGTSEN  NOR          1292      1500m
# 1     3:28.71   Timothy CHERUIYOT  KEN          1263      1500m
# 2     3:28.80         Brian KOMEN  KEN          1262      1500m
# 3     3:29.13        Yared NUGUSE  USA          1257      1500m
# 4     3:30.59         Cole HOCKER  USA          1236      1500m
# ...       ...                 ...  ...           ...        ...
# 1949  2:12:54      Wataru TOCHIGI  JPN          1113   Marathon
# 1970  2:13:18       Takayuki IIDA  JPN          1106   Marathon
# 1975  2:13:22         Saul ACOSTA  MEX          1105   Marathon
# 1989  2:13:35        Edwin KIPTOO  KEN          1102   Marathon
# 1999  2:13:44     Takuya KITASAKI  JPN          1099   Marathon
#
# [845 rows x 5 columns]

# %%
import pandas as pd

# Ensure 'Results Score' is treated as an integer or float
duplicates_sorted['Results Score'] = pd.to_numeric(duplicates_sorted['Results Score'], errors='coerce')

# Helper function to get the discipline with the highest score
def get_highest_scoring_discipline(group):
    # This returns the 'Discipline' with the highest 'Results Score' within each group
    return group.loc[group['Results Score'].idxmax(), 'Discipline']

# Aggregating data
aggregated = duplicates_sorted.groupby('Competitor').agg(
    Average_Results_Score=('Results Score', 'mean'),  # Calculate average Results Score
    Highest_Scoring_Discipline=('Results Score', get_highest_scoring_discipline),  # Get Discipline with the highest score
    Disciplines=('Discipline', set),  # Set of all disciplines for uniqueness
    Discipline_Count=('Discipline', 'count')  # Count of disciplines
)

# Display the DataFrame with the new structure
aggregated
# Out:
# <ipython-input-36-e97f7bea4505>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_sorted['Results Score'] = pd.to_numeric(duplicates_sorted['Results Score'], errors='coerce')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
import pandas as pd

# Sample DataFrame
data = {'Competitor': ['John Doe', 'Jane Smith', 'Alice Johnson', 'John Doe', 'Bob Lee', 'Alice Johnson'],
        'Event': ['100m', '200m', '100m', '400m', '200m', '400m'],
        'Score': [9.8, 23.4, 12.1, 48.6, 22.1, 49.3]}
df = pd.DataFrame(data)

# Finding duplicates in the "Competitor" column
duplicates_competitor = df[df.duplicated('Competitor', keep=False)]
print("Duplicate rows based on the 'Competitor' column:\n", duplicates_competitor)
# Out:
# Duplicate rows based on the 'Competitor' column:
#        Competitor Event  Score
# 0       John Doe  100m    9.8
# 2  Alice Johnson  100m   12.1
# 3       John Doe  400m   48.6
# 5  Alice Johnson  400m   49.3

# %%
# Find the table, you might need to add specific classes or ids depending on the HTML structure
table = soup.find('table')

# Initialize a list to store your data
results = []

# Assuming each row in the table (except for the header) contains the data
for row in table.find_all('tr')[1:]:  # [1:] skips the header row
    cols = row.find_all('td')
    if len(cols) > 1:  # This checks if the row contains data
        mark = cols[1].text.strip()
        competitor = cols[3].text.strip()
        nationality = cols[5].text.strip()
        result_score = cols[-1].text.strip()  # Assuming Result Score is in the last column

        results.append({
            'Mark': mark,
            'Competitor': competitor,
            'Nat': nationality,
            'Results Score': result_score
        })

# Now results list contains all the extracted data
print(results)
# Out:
DIKUMANA', 'Results Score': '1163'}, {'Mark': '13:12.82', 'Competitor': '', 'Nat': 'Raphael DAPASH', 'Results Score': '1163'}, {'Mark': '13:13.07', 'Competitor': '', 'Nat': 'Nicholas GRIGGS', 'Results Score': '1162'}, {'Mark': '13:13.10', 'Competitor': '', 'Nat': 'Anthony KIBE', 'Results Score': '1162'}, {'Mark': '13:13.23', 'Competitor': '', 'Nat': 'Kasey KNEVELBAARD', 'Results Score': '1162'}, {'Mark': '13:13.29', 'Competitor': '', 'Nat': 'Brian Muange MUSAU', 'Results Score': '1161'}, {'Mark': '13:13.34', 'Competitor': '', 'Nat': 'Habtom SAMUEL', 'Results Score': '1161'}, {'Mark': '13:13.38', 'Competitor': '', 'Nat': 'Sergio JIMÉNEZ', 'Results Score': '1161'}, {'Mark': '13:13.52', 'Competitor': '', 'Nat': 'Benard KIBET', 'Results Score': '1161'}, {'Mark': '13:13.56', 'Competitor': '', 'Nat': 'Tatsuhiko ITO', 'Results Score': '1160'}, {'Mark': '13:13.63', 'Competitor': '', 'Nat': 'Emmanuel KIPCHIRCHIR', 'Results Score': '1160'}, {'Mark': '13:14.01', 'Competitor': '', 'Nat': 'Yves NIMUBONA', 'Results Score': '1159'}, {'Mark': '13:14.16', 'Competitor': '', 'Nat': 'Morgan LE GUEN', 'Results Score': '1158'}, {'Mark': '13:14.26', 'Competitor': '', 'Nat': 'Adel MECHAAL', 'Results Score': '1158'}, {'Mark': '13:14.36', 'Competitor': '', 'Nat': 'Jakob INGEBRIGTSEN', 'Results Score': '1158'}, {'Mark': '13:14.64', 'Competitor': '', 'Nat': 'Thomas RATCLIFFE', 'Results Score': '1207'}, {'Mark': '13:14.78', 'Competitor': '', 'Nat': 'Elzan BIBIĆ', 'Results Score': '1156'}, {'Mark': '13:14.79', 'Competitor': '', 'Nat': 'Valentin GONDOUIN', 'Results Score': '1156'}, {'Mark': '13:14.97', 'Competitor': '', 'Nat': 'Brian FAY', 'Results Score': '1155'}, {'Mark': '13:14.99', 'Competitor': '', 'Nat': 'Narve Gilje NORDÅS', 'Results Score': '1155'}, {'Mark': '13:15.14', 'Competitor': '', 'Nat': 'William KINCAID', 'Results Score': '1205'}, {'Mark': '13:15.17', 'Competitor': '', 'Nat': 'Emmanuel KIPROP', 'Results Score': '1155'}, {'Mark': '13:15.24', 'Competitor': '', 'Nat': 'Emile HAFASHIMANA', 'Results Score': '1154'}]
df = pd.DataFrame(data)
df
# Out:
#         Mark Competitor                   Nat Results Score
# 0   12:36.73                  Hagos GEBRHIWET          1296
# 1   12:38.95                   Yomif KEJELCHA          1288
# 2   12:40.96                    Jacob KIPLIMO          1280
# 3   12:48.10             Thierry NDIKUMWENAYO          1254
# 4   12:49.65                    Addisu YIHUNE          1248
# ..       ...        ...                   ...           ...
# 95  13:14.97                        Brian FAY          1155
# 96  13:14.99               Narve Gilje NORDÅS          1155
# 97  13:15.14                  William KINCAID          1205
# 98  13:15.17                  Emmanuel KIPROP          1155
# 99  13:15.24                Emile HAFASHIMANA          1154
#
# [100 rows x 4 columns]
